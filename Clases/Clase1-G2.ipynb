# %% [markdown]
# # Lenguaje de Programación (Python)
#
# Conjunto de palabras clave (usualmente en inglés) que emplean una sintaxis y semántica propia para comunicar tareas al hardware del computador

# %% [markdown]
# ## Lenguaje de programación como una calculadora
#
# ¿ Cómo ejecutar operaciones aritméticas en Python ?
#
# `Operando1 Operador Operando2`

# %%
2 + 3
# Out:
# 5

# %%
5 - 7
# Out:
# -2

# %%
2 * 3
# Out:
# 6

# %%
13/3
# Out:
# 4.333333333333333

# %% [markdown]
# Operador potencia
# $
#     a^n
# $

# %%
2**4
# Out:
# 16

# %% [markdown]
# División entera

# %%
13//3
# Out:
# 4

# %% [markdown]
# Residuo

# %%
13%3
# Out:
# 1

# %% [markdown]
# ## Operadores aritméticos básicos
#
# - Suma `+`
# - Resta `-`
# - Multiplicación `*`
# - División `/`
# - Potencia `**`
# - División entera `//`
# - Residuo `%`

# %%
# valor absoluto
abs(-5)
# Out:
# 5

# %%
Abs(-5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1387108348.py in <cell line: 0>()
# ----> 1 Abs(-5)
#
# NameError: name 'Abs' is not defined

# %% [markdown]
# Redondeo

# %%
round(3.456)
# Out:
# 3

# %%
round(3.456,1)
# Out:
# 3.5

# %% [markdown]
# ## Expresiones aritméticas
#
# Unión de operaciones aritméticas básicas que se ejecutan en una misma línea de código

# %%
4 - 7 + 3/4 + 5*7/8
# Out:
# 2.125

# %% [markdown]
# LaTeX
#
# $
#     \frac{1 - 7}{ 4 \times 5 - 23}
# $

# %%
(1-7)/(4*5 - 23)
# Out:
# 2.0

# %%
1-7/(4*5 - 23)
# Out:
# 3.3333333333333335

# %% [markdown]
# *Ej*: Calcular la nota definitiva del curso de Herramientas de Programación, para un estudiante con las siguientes notas:
#
# - Taller 1: `4.6`
# - Taller 2: `3.4`
# - Quices: `3.9, 4.5, 2.8, 3.7`
# - Proyecto: `3.6`

# %%
round( (4.6 + 3.4)/2*0.33 + (3.9 + 4.5 + 2.8 + 3.7)/4*0.33 + 3.6*0.34, 1 )
# Out:
# 3.8

# %% [markdown]
# ## Cadenas de caracteres (Strings)
# Conjunto de símbolos alfa-numéricos que conforman un texto

# %%
round(3.14)
# Out:
# 3

# %%
"round(3.14)"
# Out:
# 'round(3.14)'

# %%
'round(3.14)'
# Out:
# 'round(3.14)'

# %% [markdown]
# ## Comentarios
# Cadenas de caracteres especiales (no necesitan comillas), que se usan para anotar una porción de código

# %%
# suma de dos numeros
4 + 6
# Out:
# 10

# %% [markdown]
# Operaciones básicas con cadenas de caracteres

# %%
# transformar la cadena a minusculas
"ANDRES".lower()
# Out:
# 'andres'

# %%
# transformar la cadena a mayusculas
"andres".upper()
# Out:
# 'ANDRES'

# %%
# poner el caracter inicial en mayuscula"
"andres".capitalize()
# Out:
# 'Andres'

# %%
# operador de indexacion
"andres"[5]
# Out:
# 's'

# %% [markdown]
# Concatenación de cadenas

# %%
"3" + "4"
# Out:
# '34'

# %%
"andres" + " " + "urquijo"
# Out:
# 'andres urquijo'

# %% [markdown]
# Multiplicidad de cadenas

# %%
"Hola "*100
# Out:
# 'Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola '

# %%
100*"Hola "
# Out:
# 'Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola Hola '

# %%
4+5
"Hola"
5/6
# Out:
# 0.8333333333333334

# %% [markdown]
# Función `print`

# %%
print( 4+5 )
print("Hola")
print(5/6)
# Out:
# 9
# Hola
# 0.8333333333333334

# %% [markdown]
# *Ej*
#
# ```
# -
# - -
# - - -
# - - - -
# .
# .
# .
# - - - - - - - - -
# ```

# %%
print("- "*1)
print("- "*2)
print("- "*3)
print("- "*4)
print("- "*5)
print("- "*6)
print("- "*7)
print("- "*8)
print("- "*9)
print("- "*10)
# Out:
# -
# - -
# - - -
# - - - -
# - - - - -
# - - - - - -
# - - - - - - -
# - - - - - - - -
# - - - - - - - - -
# - - - - - - - - - -

# %% [markdown]
# Método `split`

# %%
"1,2,3,4".split("3")
# Out:
# ['1,2,', ',4']

# %% [markdown]
# Función `len`

# %%
len( "* "*100 )
# Out:
# 200
